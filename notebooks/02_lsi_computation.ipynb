# %% [markdown]
# # 02 Lsi Computation
#
# Compute 6 Local Singularity Index maps (Theorem 1, Cheng 2007)
#
# **FractalProspect-Net v4 — Zimbabwe Gold Prospectivity**
# Romeo Thando | MSU Applied Mathematics & Computational Science

# %%
import sys
sys.path.insert(0, '..')
from src.config import *
print(f'N_SPECTRAL={N_SPECTRAL}, N_STOCHASTIC={N_STOCHASTIC}, N_TOTAL={N_TOTAL}')
